# %% [markdown]
# <a href="https://colab.research.google.com/github/jikku007/Machine-Learning-Masters/blob/master/pauleralitest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q llama-index
# !pip install -q llama-parse
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.3/454.3 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 1.9 MB/s eta 0:00:00

# %%
import nest_asyncio

from llama_index.llms.openai import OpenAI
from llama_index.core import VectorStoreIndex
from IPython.display import Image, Markdown

from llama_parse import LlamaParse

from llama_index.core.node_parser import MarkdownElementNodeParser

# %%
nest_asyncio.apply()

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-..."

llm_gpt4o_mini = OpenAI(model="gpt-4o-mini")

# %%
parser = LlamaParse(
    api_key='llx-Tk8kC7sfsjv6gZRmneLcj4l0szAN3L3sk1eiJ1VvRs4Lo858',
    result_type="markdown",
)

documents = parser.load_data("/Sales-Weekly-Meeting 2024-Plan-Paul Eralil.xlsx")
# Out:
# Started parsing the file under job_id df15a78f-98a7-4959-945e-cbf99d46c6cd

# %%
len(documents)
# Out:
# 1

# %%
print(documents[0].get_content())
# Out:
# # 2024
#
# |Customer Name                                        |Opportunity                           |Sales activities for the current week              |Support Required                      |Comments                                                                 |Approx Value - QAR|
# |-----------------------------------------------------|--------------------------------------|---------------------------------------------------|--------------------------------------|-------------------------------------------------------------------------|------------------|
# |Week 49 8- 12Dec 2024                                |                                      |                                                   |                                      |                                                                         |                  |
# ...

# %%
node_parser = MarkdownElementNodeParser(llm=llm_gpt4o_mini, num_workers=4)

# %%
nodes = node_parser.get_nodes_from_documents([documents[0]])
# Out:
# 1it [00:00, 1289.76it/s]
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-18-3a75d344805e> in <cell line: 1>()
# ----> 1 nodes = node_parser.get_nodes_from_documents([documents[0]])
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/interface.py in get_nodes_from_documents(self, documents, show_progress, **kwargs)
#     163             CBEventType.NODE_PARSING, payload={EventPayload.DOCUMENTS: documents}
#     164         ) as event:
# --> 165             nodes = self._parse_nodes(documents, show_progress=show_progress, **kwargs)
#     166             nodes = self._postprocess_parsed_nodes(nodes, doc_id_to_document)
#     167
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     319
#     320             try:
# ...
